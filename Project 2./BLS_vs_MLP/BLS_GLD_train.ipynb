# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns

def black_scholes_call(S, K, T, r, sigma):
    if T <= 0 or sigma <= 0:
        return max(S - K, 0)
    d1 = (np.log(S / K) + (r + 0.5*sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    call = S * norm.cdf(d1) - K * np.exp(-r*T) * norm.cdf(d2)
    return max(call, max(S - K, 0))

def black_scholes_put(S, K, T, r, sigma):
    if T <= 0 or sigma <= 0:
        return max(K - S, 0)
    d1 = (np.log(S / K) + (r + 0.5*sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    put = K * np.exp(-r*T) * norm.cdf(-d2) - S * norm.cdf(-d1)
    return max(put, max(K - S, 0))


def mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)

def mae(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mape(y_true, y_pred, epsilon=0.01):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / np.maximum(y_true, epsilon))) * 100

def log_error(y_true, y_pred):
    return np.mean(np.abs(np.log1p(y_pred) - np.log1p(y_true)))


file_path = './Datasets/train_gld_before_2016_vola_2.xlsx'
T_days = 5
T = T_days / 252
r = 0.02

strike_cols = ['Strike_1','Strike_2','Strike_3','Strike_4','Strike_5']
close_cols = ['Close_1','Close_2','Close_3','Close_4','Close_5']


vol_cols = [
   '3_Day_Percent_Volatility', '9_Day_Percent_Volatility', '14_Day_Percent_Volatility',
  '21_Day_Percent_Volatility', '30_Day_Percent_Volatility', '60_Day_Percent_Volatility',
   '90_Day_Percent_Volatility'
 
]




def process_sheet(sheet_name, option_type='call', vol_col='14_Day_Percent_Volatility'):
    df = pd.read_excel(file_path, sheet_name=sheet_name, parse_dates=['Exp Date = T'])
    metrics_list = []

    all_close_values = df[close_cols].values.flatten()
    MOP = np.mean(all_close_values)

    for strike, close in zip(strike_cols, close_cols):
        pred_col = f'Predicted_{close}'
        bls_strike_col = f'BLS_{strike}'
        df[bls_strike_col] = df[strike]  

        if option_type.lower() == 'call':
            df[pred_col] = df.apply(
                lambda row: black_scholes_call(
                    S=row['ETF Price on T - 5'],
                    K=row[strike],
                    T=T,
                    r=r,
                    sigma=row[vol_col]/100
                ), axis=1
            )
        else:
            df[pred_col] = df.apply(
                lambda row: black_scholes_put(
                    S=row['ETF Price on T - 5'],
                    K=row[strike],
                    T=T,
                    r=r,
                    sigma=row[vol_col]/100
                ), axis=1
            )

        mse_val = mse(df[close], df[pred_col])
        mae_val = mae(df[close], df[pred_col])
        mape_val = mape(df[close], df[pred_col])
        logerr_val = log_error(df[close], df[pred_col])
        MAE_MOP_pct_val = mae_val / MOP * 100

        metrics_list.append({
            'Close': close,
            'MSE': mse_val,
            'MAE': mae_val,
            'MAE_MOP_pct': MAE_MOP_pct_val,
            'MAPE': mape_val,
            'LogError': logerr_val
        })

    metrics_df = pd.DataFrame(metrics_list)
    Mean_metrics = metrics_df[['MSE','MAE','MAE_MOP_pct','MAPE','LogError']].mean()
    Mean_metrics_row = {'Close':'Mean'}
    Mean_metrics_row.update(Mean_metrics.to_dict())
    metrics_df = pd.concat([metrics_df, pd.DataFrame([Mean_metrics_row])], ignore_index=True)


    df['Mean_Actual'] = df[close_cols].mean(axis=1)
    pred_cols_list = [f'Predicted_{c}' for c in close_cols]
    df['Mean_Predicted'] = df[pred_cols_list].mean(axis=1)

    plt.figure(figsize=(14,6))
    plt.plot(df['Exp Date = T'], df['Mean_Actual'], label='Mean Actual', linestyle='-', marker='o')
    plt.plot(df['Exp Date = T'], df['Mean_Predicted'], label='Mean Predicted', linestyle='--', marker='x')
    plt.title(f'{sheet_name} - Mean Actual vs Predicted Option Prices ({vol_col})')
    plt.xlabel('Date')
    plt.ylabel('Mean Option Price')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    export_cols = ['Exp Date = T', 'T - 5', 'ETF Price on T - 5']
    for strike, close in zip(strike_cols, close_cols):
        export_cols.extend([strike, f'BLS_{strike}', close, f'Predicted_{close}'])
    df_export = df[export_cols]
    df_export['Vol_Used'] = vol_col

    return df_export, metrics_df


all_vol_metrics = [] 

for vol_column in vol_cols:
    print(f"\n=== Processing Volatility Column: {vol_column} ===")
    
    call_df, call_metrics_df = process_sheet('GLD_CALL', option_type='call', vol_col=vol_column)
    print("Call Metrics:")
    print(call_metrics_df)
    
    put_df, put_metrics_df = process_sheet('GLD_PUT', option_type='put', vol_col=vol_column)
    print("Put Metrics:")
    print(put_metrics_df)
    
    call_metrics_df['Vol_Used'] = vol_column
    put_metrics_df['Vol_Used'] = vol_column
    all_vol_metrics.append(pd.concat([call_metrics_df.assign(Type='Call'), put_metrics_df.assign(Type='Put')]))

    output_file = f"./BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_{vol_column}.xlsx"
    with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
        call_df.to_excel(writer, sheet_name='Call', index=False)
        call_metrics_df.to_excel(writer, sheet_name='Call Metrics', index=False)
        put_df.to_excel(writer, sheet_name='Put', index=False)
        put_metrics_df.to_excel(writer, sheet_name='Put Metrics', index=False)
    print(f"Saved results to '{output_file}'")


combined_metrics_df = pd.concat(all_vol_metrics, ignore_index=True)
Mean_metrics = combined_metrics_df.groupby('Type')[['MSE','MAE','MAE_MOP_pct','MAPE','LogError']].mean().reset_index()
print("\n=== Mean Metrics Across All Volatilities ===")
print(Mean_metrics)

Mean_metrics.to_excel('./BLS_MLP_results/train/GLD_BLS_Mean_Metrics_All_Volatilities_train.xlsx', index=False)
print("Saved Mean metrics across all volatilities to 'GLD_BLS_Mean_Metrics_All_Volatilities_train.xlsx'")

def extract_days(vol_name):
    return int(vol_name.split('_')[0])

combined_metrics_df['Vol_Days'] = combined_metrics_df['Vol_Used'].apply(extract_days)
combined_metrics_df = combined_metrics_df.sort_values('Vol_Days')

metrics_to_plot = ['MAPE','MAE','MSE']


for metric in metrics_to_plot:
    plt.figure(figsize=(10,6))
    for option_type in ['Call','Put']:
        df_plot = combined_metrics_df[combined_metrics_df['Type'] == option_type]
        Mean_metric = df_plot.groupby('Vol_Days')[metric].mean().reset_index()
        plt.plot(Mean_metric['Vol_Days'], Mean_metric[metric], marker='o', label=f'{option_type} Mean {metric}')

    plt.title(f'Mean {metric} vs Volatility Window')
    plt.xlabel('Volatility Window (Days)')
    plt.ylabel(f'Mean {metric}')
    plt.xticks(Mean_metric['Vol_Days'])
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# === Processing Volatility Column: 3_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.518071  0.591894    44.555809  26.655048  0.206830
# 1  Close_2  0.841880  0.821616    61.848532  48.987558  0.369164
# 2  Close_3  1.204231  1.021472    76.893070  84.620617  0.607224
# 3  Close_4  0.866648  0.838663    63.131782  98.268992  0.579082
# 4  Close_5  0.499693  0.596127    44.874498  99.679858  0.442849
# 5     Mean  0.786105  0.773954    58.260738  71.642415  0.441030
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.478089  0.584727    46.781489  99.936495  0.438142
# 1  Close_2  0.826761  0.810635    64.855391  99.554208  0.569506
# 2  Close_3  1.217222  1.022062    81.770738  91.336598  0.637102
# 3  Close_4  0.960043  0.890218    71.222429  60.349800  0.444298
# 4  Close_5  0.641411  0.685266    54.825127  37.055716  0.282064
# 5     Mean  0.824705  0.798582    63.891035  77.646563  0.474222
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_3_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 9_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.502301  0.585729    44.091734  26.383682  0.204008
# 1  Close_2  0.779038  0.796371    59.948166  47.500051  0.353887
# 2  Close_3  1.038073  0.951127    71.597739  78.964080  0.550465
# 3  Close_4  0.788594  0.807036    60.750991  95.482031  0.550643
# 4  Close_5  0.476454  0.586780    44.170905  98.823584  0.434155
# 5     Mean  0.716892  0.745409    56.111907  69.430686  0.418631
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.469048  0.581662    46.536203  99.695152  0.435182
# 1  Close_2  0.783340  0.795122    63.614256  98.269099  0.554889
# 2  Close_3  1.078348  0.967871    77.435176  87.030940  0.590853
# 3  Close_4  0.888602  0.862996    69.044563  58.375635  0.423438
# 4  Close_5  0.606717  0.671573    53.729648  36.114436  0.272093
# 5     Mean  0.765211  0.775845    62.071969  75.897052  0.455291
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_9_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 14_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.484079  0.577548    43.475913  26.013749  0.200437
# 1  Close_2  0.725331  0.771113    58.046841  45.971453  0.339481
# 2  Close_3  0.932964  0.901195    67.838985  74.863721  0.512535
# 3  Close_4  0.728269  0.778449    58.599060  92.692755  0.525704
# 4  Close_5  0.453235  0.575757    43.341103  97.668711  0.424182
# 5     Mean  0.664776  0.720812    54.260380  67.442078  0.400468
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.456110  0.576383    46.113930  99.209339  0.430239
# 1  Close_2  0.739826  0.776702    62.140523  96.546505  0.538105
# 2  Close_3  0.979618  0.924176    73.939273  83.409424  0.555548
# 3  Close_4  0.830910  0.837542    67.008077  56.516238  0.405565
# 4  Close_5  0.578359  0.659046    52.727399  35.294637  0.264113
# 5     Mean  0.716965  0.754770    60.385840  74.195229  0.438714
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_14_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 21_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.454243  0.561783    42.289148  25.254457  0.193471
# 1  Close_2  0.653032  0.732627    55.149771  43.596861  0.318127
# 2  Close_3  0.812071  0.837434    63.039270  69.481515  0.465635
# 3  Close_4  0.653716  0.737392    55.508427  88.183161  0.490060
# 4  Close_5  0.424270  0.558870    42.069900  95.476780  0.408749
# 5     Mean  0.599466  0.685621    51.611303  64.398555  0.375209
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.434991  0.565957    45.279747  97.978166  0.420499
# 1  Close_2  0.678576  0.746540    59.727390  93.349278  0.511176
# 2  Close_3  0.862007  0.865747    69.264651  78.302214  0.510128
# 3  Close_4  0.754059  0.799326    63.950577  53.746551  0.380705
# 4  Close_5  0.539158  0.639375    51.153586  33.978252  0.252212
# 5     Mean  0.653758  0.723389    57.875190  71.470892  0.414944
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_21_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 30_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.416635  0.540392    40.678958  24.253548  0.184547
# 1  Close_2  0.574476  0.687833    51.777782  40.884142  0.294568
# 2  Close_3  0.694703  0.771457    58.072751  63.924212  0.419583
# 3  Close_4  0.571410  0.689430    51.898046  82.842470  0.450198
# 4  Close_5  0.384563  0.534754    40.254547  92.299250  0.387306
# 5     Mean  0.528357  0.644773    48.536417  60.840725  0.347240
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.404926  0.550031    44.005567  96.008387  0.405945
# 1  Close_2  0.607715  0.709048    56.727813  89.219381  0.478774
# 2  Close_3  0.745809  0.804123    64.334383  72.878908  0.464315
# 3  Close_4  0.667148  0.753484    60.282999  50.535992  0.352719
# 4  Close_5  0.491550  0.614007    49.124012  32.392257  0.238226
# 5     Mean  0.583430  0.686139    54.894955  68.206985  0.387996
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_30_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 60_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.313984  0.461747    34.758830  20.503201  0.153608
# 1  Close_2  0.389340  0.551593    41.522108  32.466549  0.227219
# 2  Close_3  0.444759  0.596206    44.880456  48.768385  0.306048
# 3  Close_4  0.380404  0.547462    41.211166  65.610776  0.339278
# 4  Close_5  0.279780  0.449231    33.816597  78.804472  0.314549
# 5     Mean  0.361654  0.521248    39.237831  49.230676  0.268140
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.316670  0.485394    38.834297  86.100150  0.349014
# 1  Close_2  0.430838  0.587961    47.040173  74.380156  0.379899
# 2  Close_3  0.492827  0.636937    50.958555  57.574798  0.348858
# 3  Close_4  0.459803  0.612858    49.032123  40.714710  0.274570
# 4  Close_5  0.369427  0.530223    42.420843  27.377204  0.197273
# 5     Mean  0.413913  0.570675    45.657198  57.229404  0.309923
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_60_Day_Percent_Volatility.xlsx'
#
# === Processing Volatility Column: 90_Day_Percent_Volatility ===
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Call Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.243254  0.382483    28.792050  16.705591  0.124391
# 1  Close_2  0.278612  0.435558    32.787350  25.196376  0.173961
# 2  Close_3  0.308130  0.460076    34.633005  36.753933  0.226178
# 3  Close_4  0.267090  0.426316    32.091632  49.978413  0.253012
# 4  Close_5  0.208018  0.362569    27.293021  62.953028  0.245538
# 5     Mean  0.261021  0.413400    31.119412  38.317468  0.204616
# /tmp/ipykernel_140420/989972324.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_export['Vol_Used'] = vol_col
# Put Metrics:
#      Close       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Close_1  0.248052  0.412526    33.004401  72.861290  0.288241
# 1  Close_2  0.314998  0.477341    38.189943  59.690243  0.296545
# 2  Close_3  0.345631  0.502525    40.204848  44.787706  0.264140
# 3  Close_4  0.328372  0.488897    39.114522  32.000327  0.211651
# 4  Close_5  0.281270  0.442420    35.396089  22.352697  0.159410
# 5     Mean  0.303665  0.464742    37.181961  46.338453  0.243997
# Saved results to './BLS_MLP_results/train/BLS_Predictions_train/GLD_BLS_Predictions_90_Day_Percent_Volatility.xlsx'
#
# === Mean Metrics Across All Volatilities ===
#    Type       MSE       MAE  MAE_MOP_pct       MAPE  LogError
# 0  Call  0.559753  0.643603    48.448284  60.186086  0.350762
# 1   Put  0.608807  0.682020    54.565450  67.283511  0.389298
# Saved Mean metrics across all volatilities to 'GLD_BLS_Mean_Metrics_All_Volatilities_train.xlsx'

# %%
import matplotlib.pyplot as plt

def extract_days(vol_name):
    return int(vol_name.split('_')[0])

combined_metrics_df['Vol_Days'] = combined_metrics_df['Vol_Used'].apply(extract_days)
combined_metrics_df = combined_metrics_df.sort_values('Vol_Days')

metrics_to_plot = ['MAPE','MAE','MSE','MAE_MOP_pct']
mid_term_range = (14, 30)


fig, axes = plt.subplots(2, 2, figsize=(20,12))
axes = axes.flatten() 

handles_labels = [] 

for i, metric in enumerate(metrics_to_plot):
    ax = axes[i]
    for option_type in ['Call','Put']:
        df_plot = combined_metrics_df[combined_metrics_df['Type'] == option_type]
        Mean_metric = df_plot.groupby('Vol_Days')[metric].mean().reset_index()

        color_line = 'green' if option_type == 'Call' else 'red'
        color_mean = 'darkgreen' if option_type == 'Call' else 'darkred'

        line, = ax.plot(Mean_metric['Vol_Days'], Mean_metric[metric], marker='o', color=color_line)
        if i == 0:
            handles_labels.append((line, f'{option_type} Mean'))

        mid_mask = (Mean_metric['Vol_Days'] >= mid_term_range[0]) & (Mean_metric['Vol_Days'] <= mid_term_range[1])
        scatter = ax.scatter(Mean_metric['Vol_Days'][mid_mask], Mean_metric[metric][mid_mask],
                             color=color_line, s=100, edgecolor='k')
        if i == 0:
            handles_labels.append((scatter, f'{option_type} Mid-Term'))

        mean_line = ax.axhline(Mean_metric[metric].mean(), linestyle='--', color=color_mean, alpha=0.8)
        if i == 0:
            handles_labels.append((mean_line, f'{option_type} Overall Mean'))

    ax.set_title(f'Mean {metric}', fontsize=14)
    ax.set_xlabel('Volatility Window (Days)', fontsize=13)
    ax.set_ylabel(metric, fontsize=12)
    ax.set_xticks(Mean_metric['Vol_Days'])
    ax.tick_params(axis='both', labelsize=13)
    ax.grid(True)

plt.suptitle('Black-Scholes GLD Options 2010-2015: Metrics vs Volatility Window - Train set', fontsize=18)
fig.text(0.5, 0.01, 'Note: GLD = SPDR Gold Shares ETF', ha='center', fontsize=14, style='italic')

handles, labels = zip(*handles_labels)
fig.legend(handles, labels, loc='upper right', bbox_to_anchor=(1.02, 0.95), fontsize=12, frameon=True)

plt.tight_layout(rect=[0, 0.03, 0.95, 0.95])

plt.savefig('./BLS_MLP_results/train/Figures_Plots/GLD_BLS_Metrics_2x2_Grid_train.pdf', format='pdf', bbox_inches='tight')
print("Saved GLD_BLS_Metrics_2x2_Grid_train.pdf")

plt.show()
# Out:
# Saved GLD_BLS_Metrics_2x2_Grid_train.pdf

# %%
import pandas as pd
import re

# Read MLP metric CSVs
mlp_mae = pd.read_csv('mlp_results_data/mlp_mae.csv', index_col=0)
mlp_mse = pd.read_csv('mlp_results_data/mlp_mse.csv', index_col=0)
mlp_mape = pd.read_csv('mlp_results_data/mlp_mape.csv', index_col=0)
mlp_mae_pct = pd.read_csv('mlp_results_data/mlp_mae_mop_percent_.csv', index_col=0)

mlp_dict = {
    'MAE': mlp_mae,
    'MSE': mlp_mse,
    'MAPE': mlp_mape,
    'MAE_MOP_pct': mlp_mae_pct
}

# Helper functions
def get_vol_days(model_name):
    match = re.search(r'with (\d+)d v', model_name)
    return int(match.group(1)) if match else 0

def get_optimizer(model_name):
    return 'Adam' if 'Adam' in model_name else 'SGD'

# Add Vol_Days and Optimizer columns to each MLP DataFrame
for df in mlp_dict.values():
    df['Vol_Days'] = df.index.map(get_vol_days)
    df['Optimizer'] = df.index.map(get_optimizer)

# Process combined_metrics_df
def extract_days(vol_name):
    return int(vol_name.split('_')[0])

combined_metrics_df['Vol_Days'] = combined_metrics_df['Vol_Used'].apply(extract_days)
combined_metrics_df = combined_metrics_df.sort_values('Vol_Days')

# Generate results for CSV
metrics_to_include = ['MAE', 'MSE', 'MAPE', 'MAE_MOP_pct']
results_list = []

all_vols = sorted(combined_metrics_df['Vol_Days'].unique())

for metric in metrics_to_include:
    bls_call = combined_metrics_df[combined_metrics_df['Type']=='Call'].groupby('Vol_Days')[metric].mean().reset_index()
    bls_put  = combined_metrics_df[combined_metrics_df['Type']=='Put'].groupby('Vol_Days')[metric].mean().reset_index()

    mlp_df = mlp_dict[metric]

    for vol in bls_call['Vol_Days']:
        row = {
            'Metric': metric,
            'Vol_Days': vol,
            'BLS_Call': bls_call[bls_call['Vol_Days']==vol][metric].values[0],
            'BLS_Put':  bls_put[bls_put['Vol_Days']==vol][metric].values[0],
        }
        for opt in ['Adam', 'SGD']:
            mlp_opt = mlp_df[mlp_df['Optimizer']==opt]
            mlp_grouped = mlp_opt.groupby('Vol_Days')[['Call Train','Put Train']].mean()
            row[f'MLP_Call_{opt}'] = mlp_grouped.at[vol, 'Call Train'] if vol in mlp_grouped.index else None
            row[f'MLP_Put_{opt}']  = mlp_grouped.at[vol, 'Put Train'] if vol in mlp_grouped.index else None
        results_list.append(row)

# Save CSV
results_df = pd.DataFrame(results_list)
results_df.to_csv('./BLS_MLP_results/train/BLS_vs_MLP_Train_Metrics_by_Volatility.csv', index=False)
print("Saved results to BLS_vs_MLP_Train_Metrics_by_Volatility.csv")
# Out:
# Saved results to BLS_vs_MLP_Train_Metrics_by_Volatility.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


df = pd.read_csv('./BLS_MLP_results/train/BLS_vs_MLP_Train_Metrics_by_Volatility.csv')

df = df[df['Metric'].isin(['MAPE', 'MAE_MOP_pct'])]

call_models = ['BLS_Call','MLP_Call_Adam','MLP_Call_SGD']
put_models  = ['BLS_Put','MLP_Put_Adam','MLP_Put_SGD']
all_models = call_models + put_models
metrics = df['Metric'].unique()

combined_mean_df = pd.DataFrame(index=metrics, columns=all_models)

for metric in metrics:
    df_metric = df[df['Metric'] == metric]
    combined_mean_df.loc[metric, call_models] = df_metric[call_models].mean()
    combined_mean_df.loc[metric, put_models]  = df_metric[put_models].mean()

combined_mean_df = combined_mean_df.astype(float)


mop_csv = pd.read_csv('./BLS_MLP_results/train/BLS_MLP_mean_option_prices_train.csv')

def build_label(row):
    if row['Label'] == 'BLS' or pd.isna(row['Optimizer']) or row['Optimizer'] == 'None':
        return f"{row['Label']}_{row['OptionType']}"
    return f"{row['Label']}_{row['OptionType']}_{row['Optimizer']}"

mop_csv['FullLabel'] = mop_csv.apply(build_label, axis=1)

mean_option_prices = dict(zip(mop_csv['FullLabel'], mop_csv['MeanOptionPrice']))
mop_row = pd.DataFrame([mean_option_prices], index=["Mean Option Price USD$"]).reindex(columns=all_models)

combined_mean_df_plot = pd.concat([combined_mean_df, mop_row])


mask = np.zeros_like(combined_mean_df_plot, dtype=bool)
mask[-1, :] = True  

plt.figure(figsize=(12,6))
ax = sns.heatmap(
    combined_mean_df_plot,
    annot=False,
    fmt=".4f",
    cmap='coolwarm',
    linewidths=0.5,
    cbar_kws={'label':'Metric Value'},
    mask=mask
)

for i in range(combined_mean_df_plot.shape[0]):
    for j, col in enumerate(combined_mean_df_plot.columns):
        val = combined_mean_df_plot.iloc[i, j]
        if i == combined_mean_df_plot.shape[0]-1:  # MOP row
            ax.add_patch(plt.Rectangle((j, i), 1, 1, fill=True, color='white', zorder=0))
            ax.text(j + 0.5, i + 0.5, f"{val:.4f}",
                    ha='center', va='center', fontsize=14, fontweight='bold', color='black')
        else:
            ax.text(j + 0.5, i + 0.5, f"{val:.4f}",
                    ha='center', va='center', fontsize=14, fontweight='bold', color='black')

divider_pos = len(call_models)
plt.axvline(divider_pos, color='black', linestyle='--', linewidth=2)

plt.title('Black-Scholes (BLS) vs MLP 8L 3600N (Adam & SGD) — TRAIN GLD (2010-2015) — MAPE & MAE/MOP %', fontsize=14)
plt.xlabel('Model', fontsize=14)
plt.ylabel('Metric', fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.yticks(rotation=0, fontsize=12)
plt.text(0.5, -0.6, 'Mean across volatility window metrics | GLD = SPDR Gold Shares ETF options',
         ha='center', va='center', fontsize=12, transform=plt.gca().transAxes, style='italic')

plt.tight_layout()
plt.savefig('./BLS_MLP_results/train/Figures_Plots/GLD_BLS_vs_MLP_Call_Put_train.pdf', bbox_inches='tight')
plt.show()
